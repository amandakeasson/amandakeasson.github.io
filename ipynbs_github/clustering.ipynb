# %%
## import

from sklearn.cluster import AffinityPropagation as affinity

from __future__ import division # to get integer division
import pickle

import scipy.io as sio
from nilearn import plotting, image
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, linalg, ndimage, signal
from pylab import *

# from sklearn import datasets

from sklearn.svm import SVC
from sklearn.linear_model import Lasso, LassoCV
from sklearn.cross_validation import KFold, cross_val_score, permutation_test_score, train_test_split, StratifiedKFold
from sklearn.dummy import DummyClassifier
import sklearn.feature_selection
from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.tree import DecisionTreeClassifier

from nilearn.decomposition.canica import CanICA
from nilearn.plotting import plot_stat_map #, show, plot_prob_atlas
from nilearn.image import iter_img
# Out:
# /Users/AmandaE/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Plotting, smoothing, detrending
firstvol = image.index_img(<imgfile>,0)
smooth_img = image.smooth_img(firstvol)
display = plotting.plot_glass_brain(smooth_img,fwhm=6)
smooth_img.to_filename(“<filename>”)
display.close()
display.savefig
plt.plot(x,y)
tsmooth = ndimage.gaussian_filter(t,sigma=2)
t_detrend = signal.detrend(t)

# Loop over each image
for volume in image.iter_img(“<nifti name>”)
    smoothed_img = image.smooth_img(volume, fwhm=6) # finish for loop

# %%
#################################### ML SETUP ######################################

filename = 'conn_static_Kids_CCS_dos_filtnoglob'

# Load MATLAB files
mat = sio.loadmat(filename)
mat1 = mat['connmat_all']

# %%
## affinity clustering

from sklearn.cluster import AffinityPropagation
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs

# compute affinity propagation
af = AffinityPropagation(preference=-50,max_iter=1000).fit(mat1[1:5,10])
cluster_centers_indices = af.cluster_centers_indices_
labels = af.labels_

n_clusters_ = len(cluster_centers_indices)

print('Estimated number of clusters: %d' % n_clusters_)

# print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
# print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
# print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
# print("Adjusted Rand Index: %0.3f"
      # % metrics.adjusted_rand_score(labels_true, labels))
# print("Adjusted Mutual Information: %0.3f"
      # % metrics.adjusted_mutual_info_score(labels_true, labels))
# print("Silhouette Coefficient: %0.3f"
      # % metrics.silhouette_score(X, labels, metric='sqeuclidean'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-d600475a11f7> in <module>()
#      10 labels = af.labels_
#      11
# ---> 12 n_clusters_ = len(cluster_centers_indices)
#      13
#      14 print('Estimated number of clusters: %d' % n_clusters_)
#
# TypeError: object of type 'NoneType' has no len()

# %%
mat1[:,0:2]
# Out:
# array([[  2.26731156e-01,   9.67764861e-02],
#        [  2.49761972e-01,   3.30647725e-01],
#        [  3.74935809e-01,   4.63577579e-01],
#        [  4.73727109e-01,   4.68312916e-01],
#        [  1.25883915e-01,   2.00986730e-02],
#        [  4.98423304e-01,   3.61476007e-01],
#        [  7.25963231e-02,   8.09210968e-02],
#        [  4.62831667e-01,   2.12136076e-01],
#        [  1.28295771e-01,  -1.63022573e-01],
#        [  7.16656289e-01,   5.51252506e-01],
#        [ -1.06148459e-01,  -2.12079199e-01],
#        [  4.25946791e-01,   3.05715256e-01],
#        [  1.61601777e-01,   2.26487282e-01],
#        [  4.64893884e-01,   3.07266331e-01],
#        [  7.91002298e-02,   4.34739246e-01],
#        [  2.35723187e-01,  -1.41028758e-01],
#        [  8.41133437e-01,   7.04435382e-01],
#        [  6.35623536e-02,  -3.61348538e-01],
#        [ -1.85040483e-01,   4.67705218e-01],
#        [  7.64720927e-01,   5.63241288e-01],
#        [  2.67828870e-01,  -9.01240434e-02],
#        [  2.13706221e-01,   1.69542730e-01],
#        [  1.74783188e-01,  -7.99156785e-02],
#        [  6.43159332e-01,   6.34539424e-01],
#        [  5.44204657e-01,   5.28777110e-01],
#        [  1.35294611e-01,  -4.97054174e-02],
#        [  1.61402010e-01,   1.80724887e-01],
#        [  5.17761566e-01,  -1.42444107e-01],
#        [  2.04162076e-01,   9.56370225e-02],
#        [  2.61909483e-01,   9.18230683e-02],
#        [  6.14578796e-01,   3.06404674e-01],
#        [ -2.74823953e-02,  -2.01139419e-01],
#        [  5.37037372e-01,   4.48336747e-02],
#        [  5.70816347e-01,   4.80555214e-01],
#        [  1.88250442e-01,   2.62144584e-01],
#        [  3.68730637e-01,   1.63611961e-01],
#        [  6.15665993e-01,   1.16929059e-01],
#        [  4.18769231e-01,  -1.35485341e-01],
#        [  4.56073708e-01,   4.83863303e-01],
#        [  3.54367527e-01,  -2.89883641e-01],
#        [ -6.26397554e-02,  -4.11608228e-02],
#        [  5.41617455e-01,   7.14436807e-01],
#        [  5.64548706e-01,  -2.12133574e-01],
#        [  1.31204133e-01,   1.76076536e-01],
#        [  5.82188156e-01,   3.40497779e-01],
#        [  2.81956069e-01,   3.37010913e-01],
#        [  5.85463905e-01,   3.78110338e-01],
#        [  7.18792746e-01,   5.82664668e-01],
#        [  3.14023477e-01,   1.69832935e-01],
#        [  6.56797880e-01,   5.48709984e-01],
#        [  5.51854809e-01,   1.52265864e-03],
#        [  2.72741534e-01,   1.81396511e-01],
#        [  3.44365274e-01,   3.27437497e-01],
#        [  4.55245824e-01,  -1.59588808e-01],
#        [  4.13677407e-01,   2.50137456e-01],
#        [  4.79946276e-01,   2.04627942e-01],
#        [  2.41328493e-01,  -2.55567166e-01],
#        [  2.59208390e-03,   1.03325114e-01],
#        [  5.44407976e-01,   1.36329479e-01],
#        [  5.55477277e-01,   1.80117403e-01],
#        [  2.98132437e-01,   2.75888869e-01],
#        [  5.08621024e-01,   4.08534619e-01],
#        [  2.76959630e-02,   2.85383578e-01],
#        [ -1.53955930e-02,  -3.09149296e-02],
#        [ -1.39804314e-01,   1.39471338e-01],
#        [  5.91982137e-01,   4.02574527e-01],
#        [  6.36845927e-02,   1.44643217e-01],
#        [  1.39198856e-01,   1.38245591e-01],
#        [ -2.48014247e-02,   2.92260437e-02],
#        [  4.60181417e-01,   4.12438680e-01],
#        [  4.64763634e-01,   6.24725749e-01],
#        [  4.45490782e-01,   1.94591763e-01],
#        [  2.10443317e-01,   4.92634412e-02],
#        [  3.89206069e-01,   3.17077697e-01],
#        [  4.02076701e-01,   2.93693724e-01],
#        [  4.25783171e-01,   5.66301733e-01],
#        [  1.21670572e-01,   1.02041537e-01],
#        [ -1.07694252e-02,   2.72990562e-01],
#        [  4.58747301e-01,  -7.12316966e-02],
#        [ -1.82019953e-01,  -1.01117843e-01],
#        [ -2.25807721e-02,   3.57606393e-01],
#        [ -4.07335817e-02,   3.57399963e-01],
#        [  6.54067106e-01,   4.23893081e-01],
#        [  6.60870276e-01,   5.62576140e-01],
#        [  5.47578064e-01,   1.43323139e-01],
#        [  5.93002422e-01,   8.70985330e-02],
#        [  3.82354416e-01,   1.91934475e-01],
#        [  4.12370879e-01,   4.44945911e-01],
#        [  2.23730877e-01,   1.22621586e-01],
#        [  3.35838686e-01,  -1.07052553e-02],
#        [  4.35843637e-01,   3.14345540e-01],
#        [  1.64550709e-01,   1.96454107e-01],
#        [  2.25823666e-01,   6.35827374e-01],
#        [  2.43686160e-01,   5.86600004e-01],
#        [  8.02621878e-01,   5.96587835e-01],
#        [  1.73667423e-01,   7.86717306e-02],
#        [  1.09409329e-01,  -1.41407267e-01],
#        [  2.64967009e-01,   5.35916154e-01],
#        [  4.16589356e-01,   1.04018052e-01],
#        [  2.35127057e-01,   6.84258267e-01],
#        [  4.79026880e-01,   5.87359420e-01],
#        [  7.08162167e-01,   4.39233706e-01],
#        [  2.85305883e-01,   8.66167091e-02],
#        [  6.07051653e-01,   6.35889754e-01],
#        [  5.48115737e-01,  -1.03995800e-02],
#        [  2.59406299e-01,  -4.27222734e-01],
#        [  1.78670203e-01,   3.99048336e-01],
#        [  1.99172565e-01,   3.17313917e-01],
#        [  4.14270593e-01,   2.51286400e-01],
#        [  1.66030142e-01,   2.04685271e-01],
#        [  3.54020978e-01,   2.85565185e-01],
#        [  6.82502785e-01,   3.92852106e-01],
#        [  5.52046686e-01,   2.17092581e-01],
#        [  4.19530343e-01,  -1.45044076e-02],
#        [  6.30185624e-01,   5.27306832e-01],
#        [  1.52323290e-01,   2.44968514e-01],
#        [  5.45017782e-01,   2.47402683e-01],
#        [  3.89593028e-01,   3.03270841e-01],
#        [  1.02024328e-01,   2.46827952e-01],
#        [  2.52670845e-01,   3.81465598e-01],
#        [  3.35101311e-01,   2.38007195e-01],
#        [  5.32946701e-01,   7.88911528e-02],
#        [  2.48059266e-01,   1.46810484e-01],
#        [ -6.45084297e-02,   3.80884429e-01],
#        [  4.42921541e-01,   5.18195603e-01],
#        [  5.61093031e-01,   4.58771035e-01],
#        [  4.85765500e-01,   5.04455172e-01],
#        [  3.98740522e-01,  -1.25597953e-01],
#        [  1.76668795e-01,   3.57717178e-01],
#        [  3.71580695e-02,   4.16994827e-01],
#        [  4.85862807e-01,   2.84672780e-01],
#        [ -2.52410896e-01,  -8.88517277e-02],
#        [ -7.72523757e-02,   3.86829921e-01],
#        [  1.36727529e-01,  -2.67903671e-01],
#        [  2.49588941e-01,   1.70097201e-01],
#        [  3.13363625e-01,   1.92338593e-01],
#        [  3.45913782e-01,  -5.08808155e-02],
#        [  5.89125685e-01,   4.56601679e-01],
#        [  3.31082384e-01,   6.17774532e-02],
#        [  5.11197065e-01,   3.41697230e-01],
#        [  4.88137570e-01,   2.24430426e-01],
#        [  1.12690972e-01,  -3.69516290e-01],
#        [  7.41308284e-01,   1.97211818e-01],
#        [  2.62826218e-01,  -1.39762584e-01],
#        [  1.19503206e-01,   7.01082466e-02],
#        [ -3.32489757e-02,   1.70607063e-01],
#        [ -3.36006938e-02,   4.95286722e-01],
#        [  4.76845550e-01,   3.66174721e-01],
#        [  5.97677131e-01,   4.68263222e-01],
#        [  5.12533626e-01,   2.42182002e-01],
#        [  2.65576362e-01,   1.41392328e-02],
#        [  1.94979773e-01,   1.74951913e-01],
#        [  7.39817771e-01,   6.80709557e-01],
#        [  2.29255835e-01,   2.52164703e-01],
#        [  6.83951315e-01,   7.50243619e-02],
#        [ -4.73517918e-03,   2.00858385e-02],
#        [  2.09824374e-02,   4.37213099e-01],
#        [  2.91526751e-01,   2.41740691e-01],
#        [  1.71867408e-01,  -2.55505162e-01],
#        [ -4.07081157e-01,  -4.32314449e-01],
#        [  1.29659366e-01,   2.11538929e-01],
#        [  1.59928519e-01,  -2.10906193e-01],
#        [  4.55168907e-01,  -1.08117402e-03],
#        [  3.17259376e-02,   4.47677171e-01],
#        [  5.29001492e-01,   4.10088785e-01],
#        [  6.89843998e-01,   8.85651842e-02],
#        [  4.24609728e-01,  -1.15765619e-01],
#        [  3.70716692e-01,   8.46888350e-02],
#        [  4.75905231e-01,   8.21161701e-01],
#        [  6.61355870e-01,   5.63628485e-01],
#        [  4.63970137e-01,   4.86884439e-01],
#        [  4.51104830e-01,   2.29920822e-01],
#        [ -7.04994791e-02,   4.49518485e-02],
#        [  3.17838729e-02,   4.05956352e-02],
#        [  1.61157230e-01,   1.70441979e-01],
#        [  4.09063315e-01,   5.18820248e-02],
#        [  3.84500805e-01,  -3.59524737e-02],
#        [  2.04700252e-01,  -1.99894231e-01],
#        [  2.22547998e-01,   5.54293088e-02],
#        [  2.20490322e-01,   1.64995580e-01],
#        [  3.55987429e-01,   4.22860080e-02],
#        [  1.17356728e-01,   3.91163241e-01],
#        [  7.08813600e-01,   1.69763267e-01],
#        [  5.06947950e-01,   3.73533214e-01],
#        [  3.89858695e-02,   9.00513940e-02],
#        [ -1.61909303e-01,  -2.74247828e-01],
#        [ -6.40459644e-02,  -1.52453689e-01],
#        [  6.32882005e-01,   5.66922841e-01],
#        [  8.19538253e-01,   5.97328023e-01],
#        [  3.99570479e-01,   7.82951006e-02],
#        [  3.61522276e-01,   5.36801444e-01],
#        [  3.92761402e-01,   4.08894352e-01],
#        [  2.65657271e-01,   3.74574064e-04],
#        [  4.13421310e-01,   4.11487665e-02],
#        [  4.99110296e-01,  -1.66496778e-01],
#        [  7.73516222e-01,   2.06446427e-01],
#        [  6.66901956e-01,   1.12056959e-01],
#        [  9.39037932e-02,   2.31666123e-01],
#        [  6.79055951e-01,   4.05812939e-01],
#        [  3.47333872e-01,  -1.13613485e-01],
#        [  6.70638500e-01,   2.95380051e-01],
#        [  1.43424179e-01,  -3.33839375e-03],
#        [  5.53171435e-01,   1.37527916e-01],
#        [  3.88989569e-01,   8.48341895e-02],
#        [  3.68553908e-01,   1.03708650e-01],
#        [  3.62323611e-01,   2.56513665e-01],
#        [  4.42310978e-01,   1.29431500e-01],
#        [  4.44430499e-01,  -2.53304155e-01],
#        [  4.68803040e-01,  -9.84789733e-03],
#        [  3.73414825e-01,   1.85460598e-01],
#        [  5.59393772e-01,   1.47723819e-01],
#        [  1.27235214e-01,   4.91529065e-01],
#        [  1.09912004e-01,  -2.07023131e-01],
#        [  3.51066536e-01,  -6.84790188e-02],
#        [  1.61770568e-01,  -1.95608997e-01],
#        [  2.63066385e-01,  -1.14287914e-01],
#        [  4.99792727e-01,  -4.40549984e-04],
#        [  4.39538839e-01,  -2.38487421e-02],
#        [  5.52927097e-01,   4.41537711e-01],
#        [ -9.76954776e-02,  -3.87046200e-02],
#        [  6.23483448e-01,   2.96388331e-04],
#        [  3.08063916e-01,   9.49870417e-02],
#        [  1.58516786e-01,   1.48294115e-01],
#        [  4.73036870e-01,   6.05105463e-01],
#        [  1.70986667e-01,   4.52141102e-02],
#        [  5.01288894e-01,   5.94995918e-02],
#        [  4.88475186e-01,   2.63274847e-01],
#        [  4.34188101e-01,  -2.42976651e-01],
#        [  3.88190185e-01,   3.33856831e-01],
#        [  1.22213867e-01,  -2.17007996e-01],
#        [  2.74877670e-01,   2.03641645e-01],
#        [  4.17851093e-01,   2.75703054e-01],
#        [  1.08812942e-01,   2.64128987e-01],
#        [  3.79153901e-01,  -1.09472445e-01],
#        [  3.50225976e-01,   2.72229808e-01],
#        [  3.39925147e-01,  -5.81981618e-02],
#        [  5.83480637e-01,   2.98868477e-01],
#        [  5.21211426e-01,   5.01896981e-02],
#        [  4.26103701e-01,   2.71421880e-02],
#        [  3.44245510e-01,  -4.67145048e-02],
#        [  2.00888922e-01,   1.90121884e-01],
#        [  6.51156191e-01,   1.60771553e-01],
#        [  3.36584640e-01,   4.82513739e-01],
#        [  3.75926447e-01,   4.46531711e-01],
#        [  3.13684392e-01,   3.73875322e-01],
#        [  4.99411053e-01,   3.00397408e-01],
#        [  2.96531533e-01,   3.09759006e-01],
#        [  6.74109007e-01,   6.72867548e-01],
#        [  4.47134609e-01,  -4.57388535e-01],
#        [  5.52641954e-01,   2.77831680e-01],
#        [  7.51077695e-01,   4.65215188e-01],
#        [  6.70201800e-01,   5.18577210e-01],
#        [  3.53301960e-01,  -7.21687483e-03],
#        [  5.89272061e-01,  -1.70851925e-01],
#        [  2.78479985e-01,   3.51678283e-01],
#        [  2.07210410e-01,   3.55429660e-01],
#        [  6.11948850e-01,   6.28255454e-01],
#        [  2.70562765e-01,   2.95580899e-01],
#        [  3.52518098e-01,   4.49550947e-01],
#        [  1.62282953e-01,   3.35997478e-01],
#        [  6.16286618e-01,   4.33250741e-01],
#        [  4.97962496e-01,   1.57390183e-01],
#        [  4.53968928e-01,  -2.04829668e-01],
#        [  4.81124899e-01,   3.26077604e-01],
#        [  1.68527063e-01,   4.32806816e-01],
#        [ -2.18657991e-01,  -1.66966152e-01],
#        [  4.54265269e-01,   2.11672904e-01],
#        [  5.48744317e-01,   2.11525740e-01],
#        [  6.58577121e-01,   2.30485038e-01],
#        [  6.43471491e-01,  -1.48488251e-01],
#        [  3.97237980e-01,   3.32796005e-02],
#        [  6.27193719e-01,  -1.50138791e-02],
#        [  4.64418484e-01,   5.41510307e-01],
#        [  4.50856242e-01,   4.70200636e-01],
#        [  3.12193472e-01,   2.84771858e-01],
#        [ -2.66309833e-01,   3.32330852e-01],
#        [  4.06833329e-02,   4.66710789e-02],
#        [  4.05238458e-02,   2.07860915e-01],
#        [  5.10615220e-01,   9.78962211e-02],
#        [  4.02887579e-01,   7.17695844e-01],
#        [  7.22187882e-01,   4.86933853e-01],
#        [  5.37547496e-01,   3.97318776e-01],
#        [  1.14369090e-02,  -3.18660594e-02],
#        [  1.47225780e-01,   8.17931040e-02],
#        [  6.76549394e-01,   3.32795860e-01],
#        [  5.77348540e-01,   5.00691198e-01],
#        [  3.44542978e-01,   5.67259601e-01],
#        [  2.98214117e-01,   4.01749377e-01],
#        [  2.25842836e-01,   2.70440609e-02],
#        [  5.30026283e-01,   4.41794035e-01],
#        [  4.32140212e-01,   2.09480396e-01],
#        [  4.56484289e-01,   3.18998105e-01],
#        [  2.72565840e-01,   1.22730326e-01],
#        [  6.40412844e-01,   2.03295897e-01],
#        [  5.88201437e-01,   2.65575589e-01],
#        [  5.65899314e-01,   2.20944221e-01],
#        [  5.54331136e-01,   2.28795637e-01],
#        [  1.88601829e-01,   8.90132599e-02],
#        [  5.14283565e-01,   1.17076365e-01],
#        [  5.69061665e-02,   5.23837743e-01],
#        [  6.05077708e-03,  -3.20567748e-01],
#        [  6.26839987e-01,   3.53330700e-02],
#        [  4.80721343e-01,   3.11996405e-01],
#        [  3.51603783e-01,   1.27250211e-01],
#        [  7.42182543e-01,   3.85557461e-01],
#        [  3.58202272e-01,   4.37935464e-01],
#        [  6.06676696e-01,   4.06943474e-01],
#        [  3.37132492e-01,   2.33091563e-01],
#        [  2.27994317e-01,  -6.14257420e-03],
#        [  6.03675963e-01,   1.47427917e-01],
#        [  7.00615051e-01,   3.13645788e-01],
#        [  5.25837280e-01,   1.35276560e-01],
#        [  3.73821617e-01,   2.17870345e-01],
#        [  7.17370570e-01,   4.94255761e-01],
#        [  2.48742699e-01,  -2.72392948e-01],
#        [  7.37664820e-01,   2.17529648e-01],
#        [  2.63491472e-01,   1.96261048e-01],
#        [  3.29631523e-01,  -6.08718893e-02],
#        [  2.97134098e-01,  -1.21205813e-01],
#        [  5.71097309e-01,   4.73225598e-02],
#        [  3.50581241e-01,   5.57886522e-01],
#        [  1.76294994e-01,   3.43933300e-01],
#        [  5.32507148e-01,   3.89810710e-01],
#        [  2.65742398e-01,   4.15394334e-01],
#        [  2.77454849e-01,   5.74920464e-01],
#        [ -1.25744129e-02,  -2.67508611e-02],
#        [  5.20557502e-01,   4.22180387e-01],
#        [  2.97337176e-01,   1.19042805e-01],
#        [  3.49595525e-02,   1.80267199e-01],
#        [  1.23166805e-01,  -3.30216709e-02],
#        [  4.22599419e-01,   1.60825215e-01],
#        [  1.28744491e-01,   1.66691748e-01],
#        [  4.64828414e-01,   7.34112763e-02],
#        [  5.82507133e-01,   3.57751459e-01],
#        [  2.61072844e-01,   1.44135770e-01],
#        [  4.66124196e-01,   2.00197316e-01],
#        [  6.22115846e-01,  -1.43678003e-01],
#        [  5.75492722e-01,   1.77463733e-01],
#        [  3.51964684e-01,   3.18078709e-01],
#        [ -1.21425050e-01,  -2.69103106e-02],
#        [  4.50216760e-01,   1.82581339e-01],
#        [  4.11856114e-02,   2.23286649e-02],
#        [  6.61437705e-01,   3.19537789e-01],
#        [  5.30217066e-01,   4.03213458e-01],
#        [  5.82955968e-01,   5.46805842e-01],
#        [  4.12187652e-01,   2.36727542e-01],
#        [  4.10676096e-01,   4.32514591e-01],
#        [  2.58142291e-01,   8.41365302e-02],
#        [  2.43628935e-01,   6.06510703e-03],
#        [  5.66620463e-01,   2.66139236e-01],
#        [  6.75005172e-01,   3.55948301e-01],
#        [  5.57273310e-02,   4.40248919e-01],
#        [  3.00969243e-01,  -6.92783381e-02],
#        [  7.23596642e-01,   4.37982878e-01],
#        [ -9.40224744e-04,   2.25748661e-01],
#        [  6.39920573e-01,   4.14217297e-01],
#        [  7.06577508e-01,   3.11116820e-01],
#        [  2.11229174e-01,   6.91661960e-02],
#        [  8.03168785e-01,   5.00219981e-01],
#        [  5.59310389e-01,   1.57378581e-01],
#        [  2.72367459e-01,   3.35951631e-01],
#        [  2.64339559e-01,   6.66124542e-01],
#        [  3.84863355e-01,   1.69079161e-01],
#        [  2.70679127e-01,   4.39735244e-01],
#        [  4.10137686e-01,   5.88632028e-01],
#        [  3.17662374e-01,   9.10255854e-02],
#        [  1.08954715e-01,   3.51656469e-01],
#        [  6.63036247e-01,   6.49666826e-01],
#        [  1.90918196e-01,   2.30295298e-01],
#        [  6.93182163e-01,   1.59246845e-01],
#        [  3.37706660e-01,   3.10408763e-02],
#        [  4.88389113e-01,  -1.70221815e-01],
#        [  5.46311806e-01,   3.93857414e-01],
#        [  4.14336015e-01,   2.07412005e-01],
#        [  7.08371483e-01,   4.88901880e-01],
#        [  7.87325673e-01,   5.09139003e-01],
#        [  3.75420387e-01,   6.33523603e-01],
#        [  5.06308066e-01,   5.73184611e-01],
#        [  5.69333178e-01,  -5.37536093e-01],
#        [  3.96551531e-01,  -1.80631598e-01],
#        [  3.83010699e-01,   3.16895858e-01],
#        [  7.14196831e-01,   5.56351860e-01],
#        [  9.09566351e-02,   2.11809330e-01],
#        [  1.26890744e-01,   4.34319166e-01],
#        [  2.82174721e-01,   4.69772818e-01],
#        [  5.17366267e-01,   5.04061761e-01],
#        [ -2.55143974e-01,   4.62529905e-01],
#        [  5.58035680e-01,   4.15894101e-01],
#        [  6.00987808e-01,   1.69839757e-01],
#        [  5.29243223e-01,   5.61627543e-01],
#        [ -1.88677728e-01,   5.56586047e-01],
#        [  2.10352894e-01,   2.50745449e-01],
#        [  2.89041032e-01,   1.88139444e-01],
#        [  3.88626416e-01,   2.54784838e-01],
#        [  5.99620068e-01,   6.22777688e-01],
#        [  6.13081114e-01,   1.81790023e-01],
#        [  4.15267166e-01,   3.02997553e-01],
#        [  4.17715481e-01,  -2.45653883e-01],
#        [  7.93111543e-02,  -8.97441019e-02],
#        [  5.40520344e-01,   2.34205413e-01],
#        [  4.69872234e-01,   6.02325163e-01],
#        [  2.45967498e-01,  -1.70181421e-01],
#        [  1.42143470e-01,  -2.84034988e-04],
#        [  3.30953590e-01,   4.13601617e-01],
#        [  2.39443615e-01,   2.40762137e-01],
#        [  7.75163849e-01,   2.52493064e-01],
#        [  4.66177222e-01,   2.34893588e-01],
#        [  3.10754646e-01,  -5.98526604e-02],
#        [  5.74528006e-01,   5.21010025e-01],
#        [  1.79094750e-01,   2.24259418e-01],
#        [  4.14241673e-01,   2.99214916e-02],
#        [  1.22149280e-02,   9.52199238e-02],
#        [ -6.42412780e-02,   1.47972513e-01],
#        [  6.18821704e-01,   3.12072475e-01],
#        [  1.36887035e-01,   2.55377505e-02]])

# %%
#################################### CLASSIFIERS ######################################

# SVC
svc = SVC(kernel = ‘linear’, C=1.)
digits = datasets.load_digits()
data = digits.data
labels = digits.target
svc.fit(data[:-10], labels[:-10])
svc.predict(data[-10:])
coef = svc.coef_
coef_img = featsel.inverse_transform(coef)

# Linear SVC
lsvc = LinearSVC(C=1., penalty = "l1", dual=False)

# LDA
lda = LDA()
anova_lda = Pipeline([('anova', feature_selection), ('LDA', lda)])

#SVM-RFE
rfe = RFE(SVC(kernel='linear', C=1.), <nfeat>, step=0.25) # can change step size
rfe_svc = Pipeline([('rfe',rfe), ('svc',svc)])
cv_scores = cross_val_score(rfe_svc,X,labels, cv=cv)

# Lasso
lasso = linear_model.LassoCV()

# LASSOCV
lasso_cv = sklearn.linear_model.LassoCV(alphas=.1)
k_fold = KFold(46,3)
scores = list()
for k, (train,test) in enumerate(k_fold):
    lasso_cv.fit(matS[train], labels[train])
        lasso_cv.score(matS[test], labels[test])

# Decision tree with feature importance
clf = DecisionTreeClassifier()
clf.fit(X,y)
clf.score(X,y)
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
for i in range(10):
    print "{} feature no.{} ({})".format(i+1,indices[i],importances[indices[i]])

# %%
#################################### FEATURE SELECTION ######################################

# RFE
rfe = RFE(estimator=svc,n_features_to_select=1,step=1)
rfe.fit(X,y)
ranking = rfe.ranking_

# RFE
rfe = RFE(estimator = lsvc, n_features_to_select = 100, step=.1)
rfecv = RFECV(estimator = lsvc, n_features_to_select = 100, step = 100)
mlmat = matS
featscores = np.zeros([np.shape(mlmat)[0],np.shape(mlmat)[1]])
scores = list()
inds = np.arange(46)
for i in range(46):
    print "Subject", i+1
        inds2 = (inds!=i)
        X = mlmat[inds2,:]
        y = labels[inds2]
        Xtrain, Xcv, Ytrain, Ycv = train_test_split(matD2,labels2,test_size = 0.33, random_state=42)
        rfecv.fit(Xtrain,Ytrain)
        feats = find(rfe.ranking_==1)
        test = mlmat[i,:].reshape(1,-1)
        tempscore = rfe.predict(test)
        scores.append(tempscore[0])
        featscores[i,feats] = 1

# RFECV
rfecv = RFECV(estimator=svc, step=.25, cv=StratifiedKFold(y,2), scoring='accuracy')
rfecv.fit(X,y)
rfecv.n_features_
plt.figure()
plt.plot(range(1,len(rfecv.grid_scores_) +1), rfecv.grid_scores_)
plt.show()

# Feature selection using ANOVA
feature_selection = SelectKBest(f_classif, k=500)
anova_svc = Pipeline([('anova', feature_selection), ('svc', svc)])
anova_svc.fit(X,labels)
y_pred = anova_svc.predict(X)

# Test a range of features
kvals = np.arange(200)
scores_all = np.zeros((200,100))
svc = SVC(kernel="rbf", C=1.)
for r in range(100):
    print "Iteration =", r+1
    for i in range(200):
        # print "# features = ", i+1
        featsel = SelectKBest(f_classif,k=kvals[i]+1)
        anova_svc = Pipeline([('anova', featsel), ('svc',svc)])
        cv = KFold(n=46,n_folds=4,shuffle=True)
        scores = cross_val_score(anova_svc,matD2,labels,cv=cv)
    scores_all[:,r] = np.mean(scores)

# Test a specific # of features
featsel = SelectKBest(f_classif,k=56)
anova_svc = Pipeline([('anova', featsel), ('svc',lsvc)])
cv = KFold(n=46,n_folds=46,shuffle=True)
scores = cross_val_score(anova_svc,matSD2,labels2,cv=cv)
np.mean(scores)

# Make list of important features
kvals = np.arange(200)
scores = list()
featscores = np.zeros([np.shape(mlmat)[0],np.shape(mlmat)[1]])
mlmat = matS
featsel = SelectKBest(f_classif,k=56)
anova_svc = Pipeline([('anova', featsel), ('svc',lsvc)])
for i in range(46):
    print "Subject", i+1
        inds2 = (inds!=i)
        X = mlmat[inds2,:]
        y = labels2[inds2]
        anova_svc.fit(X,y)
        feats = lsvc.coef_
        feats = featsel.inverse_transform(feats)
        # featscores[i,feats] = 1
        featscores[i,:] = feats
        test = mlmat[i,:].reshape(1,-1)
        tempscore = anova_svc.predict(test)
        scores.append(tempscore[0])

# Select from model
mlmat = matSs
featscores = np.zeros([np.shape(mlmat)[0],np.shape(mlmat)[1]])
scores = list()
inds = np.arange(46)
for i in range(46):
    print "Subject", i+1
        inds2 = (inds!=i)
        X = mlmat[inds2,:]
        y = labels2[inds2]
        lsvc = LinearSVC(C=1., penalty="l1", dual=False).fit(X,y)
        model = SelectFromModel(lsvc,prefit=True)
        test = mlmat[i,:].reshape(1,-1)
        test= model.transform(test)
        lsvc = LinearSVC(C=1., penalty="l1", dual=False).fit(model.transform(X),y)
        tempscore = lsvc.predict(test)
        scores.append(tempscore[0])
        feats = find(rfe.ranking_==1)
        featscores[i,feats] = 1

# Full inner + outer CV
kvals = np.arange(200)
scores_all = np.zeros((200,100))
svc = SVC(kernel="rbf", C=1.)

for r in range(100):
    print "Iteration =", r+1
    XtrainT, Xtest, YtrainT, Ytest = train_test_split(matS,labels,test_size=.25,random_state=42)
    for i in range(200):
        # print "# features = ", i+1
        featsel = SelectKBest(f_classif,k=kvals[i]+1)
        anova_svc = Pipeline([('anova', featsel), ('svc',svc)])
        cv = KFold(n=46,n_folds=4,shuffle=True)
        scores = cross_val_score(anova_svc,matD2,labels,cv=cv)
    scores_all[:,r] = np.mean(scores)

# %%
#################################### CROSS VALIDATION ######################################

# Cross Validation
cv = KFold(n=len(X), n_folds=5, shuffle=True)
cv_scores = cross_val_score(svc, Xvars, labels, cv=cv, scoring='f1') # scoring optional
np.mean(cv_scores)

########################################## ICA ############################################

# CanICA

canica = CanICA(n_components=25,smoothing_fwhm = 6., memory = "nilearn_cache", memory_level=5, threshold=3., verbose=10, random_state=0) #smoothing can be None
canica.fit(func_filenames) # full path to list of nii.gz files

components_img = canica.masker_.inverse_transform(canica.components_) # makes nifti object
components_img.to_filename('canica_resting_state.nii.gz')

plot_prob_atlas(components_img, title = "All ICA Components", view_type = "filled_contours")


######################################### OTHER ###########################################

# Measure chance level
null_cv_scores = cross_val_score(DummyClassifier(), X, labels, cv=cv)

# Permutation tests
null_cv_scores = permutation_test_score(svc, X, target, cv=cv)

# Save matlab file.
sio.savemat('matfile.mat',{'matvar':pyvar})

# Save a model using pickle or joblib
s = pickle.dumps(svc)
svc2 = pickle.loads(s)
joblib.dump(svc, 'filename.pkl')
svc2 = joblib.load('filename.pkl')

# %%
svc = SVC(kernel='linear', C=1.)
from sklearn.feature_selection import RFECV

# RFE
rfe = RFE(estimator = svc, n_features_to_select = 100, step=.1)
RFECV?
rfecv = RFECV(estimator = svc, n_features_to_select = 100, step = 100)
mlmat = mat1
featscores = np.zeros([np.shape(mlmat)[0],np.shape(mlmat)[1]])
scores = list()
inds = np.arange(46)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c00267cf7b13> in <module>()
#       5 rfe = RFE(estimator = svc, n_features_to_select = 100, step=.1)
#       6 get_ipython().magic(u'pinfo RFECV')
# ----> 7 rfecv = RFECV(estimator = svc, n_features_to_select = 100, step = 100)
#       8 mlmat = mat1
#       9 featscores = np.zeros([np.shape(mlmat)[0],np.shape(mlmat)[1]])
#
# TypeError: __init__() got an unexpected keyword argument 'n_features_to_select'

# %%
for i in range(46):
    print "Subject", i+1
        inds2 = (inds!=i)
        X = mlmat[inds2,:]
        y = labels[inds2]
        Xtrain, Xcv, Ytrain, Ycv = train_test_split(matD2,labels2,test_size = 0.33, random_state=42)
        rfecv.fit(Xtrain,Ytrain)
        feats = find(rfe.ranking_==1)
        test = mlmat[i,:].reshape(1,-1)
        tempscore = rfe.predict(test)
        scores.append(tempscore[0])
        featscores[i,feats] = 1
# Out:
#   File "<ipython-input-21-52aef95985a6>", line 12
#     inds2 = (inds!=i)
#     ^
# IndentationError: unexpected indent
